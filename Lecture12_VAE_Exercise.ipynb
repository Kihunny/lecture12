# %%
import argparse
import torch
import torch.utils.data
from torch import nn, optim
from torch.nn import functional as F
from torchvision import datasets, transforms
from torchvision.utils import save_image

# %%
device = torch.device("cuda")
batch_size = 32

# %%
#make Mnist data loaders using torch.utils.data.DataLoader , datasets.MNIST

# %%
class VAE(nn.Module):
    def __init__(self):
        super(VAE, self).__init__()
        # Make 5 liner layer
        # 3 for encode mean/variance
        # 2 for decode latent z


        #encode with 3 linear layer
        #return 2 of 20 dim vector
    def encode(self, x):
        
        return 
        
        # Make latant vector using torch.exp / torch.randn_like
    def reparameterize(self, mu, logvar):
        if self.training:
            
            return 
        else:
            return mu
        
        #decode with z
    def decode(self, z):
        
        return 

        #using encode, self.reparameterize, decode make final output
    def forward(self, x):
        
        
        return

# %%
#make model and optimizer
model = VAE().to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)


def loss_function(recon_x, x, mu, logvar):
    #make loss with binary_cross_entropy
  

    # 0.5 * sum(1 + log(sigma^2) - mu^2 - sigma^2)
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())

    return BCE + KLD

# %%
def train(epoch):
    model.train()
    train_loss = 0
    for batch_idx, (data, _) in enumerate(train_loader):
        data = data.to(device)
        
        # set optimizer zero_grad to step
        
        
        if batch_idx % 1000 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader),
                loss.item() / len(data)))

    print('====> Epoch: {} Average loss: {:.4f}'.format(
        epoch, train_loss / len(train_loader.dataset)))

# %%
def test(epoch):
    model.eval()
    test_loss = 0
    with torch.no_grad():
        for i, (data, _) in enumerate(test_loader):
            data = data.to(device)
            recon_batch, mu, logvar = model(data)
            test_loss += loss_function(recon_batch, data, mu, logvar).item()

    test_loss /= len(test_loader.dataset)
    print('====> Test set loss: {:.4f}'.format(test_loss))

# %%
for epoch in range(1, 20):
    train(epoch)
    test(epoch)
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 109.556641
# Train Epoch: 1 [32000/60000 (53%)]	Loss: 103.058662
# ====> Epoch: 1 Average loss: 109.5372
# ====> Test set loss: 99.6654
# Train Epoch: 2 [0/60000 (0%)]	Loss: 115.494522
# Train Epoch: 2 [32000/60000 (53%)]	Loss: 107.656418
# ====> Epoch: 2 Average loss: 108.1837
# ====> Test set loss: 98.0415
# Train Epoch: 3 [0/60000 (0%)]	Loss: 108.939133
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-6013914593ad> in <module>()
#       1 for epoch in range(1, 20):
# ----> 2     train(epoch)
#       3     test(epoch)
#
# <ipython-input-23-35478e6a59ff> in train(epoch)
#       9         loss.backward()
#      10         train_loss += loss.item()
# ---> 11         optimizer.step()
#      12         if batch_idx % 1000 == 0:
#      13             print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
#
# ...
